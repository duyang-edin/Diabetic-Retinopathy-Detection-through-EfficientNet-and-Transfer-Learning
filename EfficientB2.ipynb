# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from joblib import load, dump
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision import models as md
from torch import nn
from torch.nn import functional as F
import re
import math
import collections
from functools import partial
from torch.utils import model_zoo
from sklearn import metrics
from collections import Counter
import json
from efficientnet_pytorch import EfficientNet
import itertools
import matplotlib.pyplot as plt
import numpy as np

from datetime import datetime, timedelta, timezone

def get_BJ_time():
    # 拿到UTC时间，并强制设置时区为UTC+0:00
    utc_dt = datetime.utcnow().replace(tzinfo=timezone.utc)
    # astimezone()将转换时区为北京时间
    bj_dt = utc_dt.astimezone(timezone(timedelta(hours=8)))
    current_time = bj_dt.strftime('%m%d_%H-%M-%S')

    return current_time

# 绘制混淆矩阵
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    Input
    - cm : 计算出的混淆矩阵的值
    - classes : 混淆矩阵中每一行每一列对应的列
    - normalize : True:显示百分比, False:显示个数
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
import random

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
SEED = 2019
seed_everything(SEED)

current_time = get_BJ_time()
print(current_time)

df_2015 = pd.read_csv('aptos-data-split/df_2015_cv.csv')
df_2019 = pd.read_csv('aptos-data-split/df_2019_cv.csv')

df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]

test_df = pd.read_csv('2019data/sample_submission.csv')

bs = 32 #smaller batch size is better for training, but may take longer
sz = 256  # get model input size
# sz = EfficientNet.get_image_size(model_name)  # get model input size
tfms = get_transforms(do_flip=True,flip_vert=True, max_rotate=0, max_zoom=1.2, max_warp=0)

# df_2015 = pd.read_csv('aptos-data-split/df_2015_cv.csv')
# df_2019 = pd.read_csv('aptos-data-split/df_2019_cv.csv')

# df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
# df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]

# test_df = pd.read_csv('2019data/sample_submission.csv')

data = (ImageList.from_df(df=df,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )

def qk(y_pred, y):
    return torch.tensor(cohen_kappa_score(torch.round(y_pred), y, weights='quadratic'), device='cuda:0')

model_name = 'efficientnet-b2'
model = EfficientNet.from_pretrained(model_name, num_classes=1)
df_2019 = pd.read_csv('aptos-data-split/df_2019_cv.csv')
df_2019['is_valid'] = [False]*2929 + [True]*733
data_2019 = (ImageList.from_df(df=df_2019,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
learn = Learner(data_2019, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = 'output/models/')
learn.data.add_test(ImageList.from_df(test_df,
                                      '2019data',
                                      folder='test_images_ben_preprocessing_sigmaX10',
                                      suffix='.png'))
# Out:
# 0331_22-15-44
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth" to /home/featurize/.cache/torch/checkpoints/efficientnet-b2-8bb594d6.pth
# 100%|██████████| 35.1M/35.1M [00:05<00:00, 6.34MB/s]
# Loaded pretrained weights for efficientnet-b2

# %%
data_2019
# Out:
# ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: FloatList
# 2.0,4.0,1.0,0.0,0.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: FloatList
# 0.0,1.0,0.0,4.0,2.0
# Path: .;
#
# Test: LabelList (1928 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: EmptyLabelList
# ,,,,
# Path: .

# %%
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='80' class='' max='91' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.91% [80/91 01:27<00:11 6.4143]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 2.29E-03

# %%
model_save_name = "Efficientb2NetWithoutPreprocessing"
# min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(20, 1.00E-03, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       55.00% [11/20 22:16<18:13]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.096105</td>
#       <td>1.352038</td>
#       <td>0.511801</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.560003</td>
#       <td>0.448401</td>
#       <td>0.835998</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.433288</td>
#       <td>0.460588</td>
#       <td>0.845265</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.403201</td>
#       <td>0.353279</td>
#       <td>0.880387</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.362962</td>
#       <td>0.553256</td>
#       <td>0.836253</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.349251</td>
#       <td>0.691164</td>
#       <td>0.842743</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.342733</td>
#       <td>0.462427</td>
#       <td>0.862009</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.311910</td>
#       <td>0.298106</td>
#       <td>0.903199</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.276209</td>
#       <td>0.329537</td>
#       <td>0.895220</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.251607</td>
#       <td>0.300454</td>
#       <td>0.885786</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.274808</td>
#       <td>0.357410</td>
#       <td>0.886526</td>
#       <td>02:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [23/23 00:23<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 1.3520383834838867.
# Better model found at epoch 1 with valid_loss value: 0.44840118288993835.
# Better model found at epoch 3 with valid_loss value: 0.35327884554862976.
# Better model found at epoch 7 with valid_loss value: 0.29810643196105957.
# Epoch 11: early stopping
# Model save as: EfficientNetWithoutPreprocessing

# %%
df_2019test = pd.read_csv('2019data/train.csv')
train_2019="2019data/train_images_ben_preprocessing_sigmaX10/"
df_2019test['path'] = df_2019test['id_code'].map(lambda x: os.path.join(train_2019, '{}.png'.format(x)))

# %%
df_2019test['is_valid'] = [False]*2929 + [True]*733 
data_2020 = (ImageList.from_df(df=df_2019test,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
learn = Learner(data_2020, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = 'output/models/')

# %%
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='80' class='' max='91' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.91% [80/91 00:17<00:02 6.6337]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.29E-04
# Min loss divided by 10: 3.31E-03

# %%
model_save_name = "EfficientNetB2WithPreprocessing"
# min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(20, 2.29E-04, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [12/20 04:25<02:57]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.197207</td>
#       <td>3.233546</td>
#       <td>0.186719</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.012474</td>
#       <td>0.567732</td>
#       <td>0.795469</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.583647</td>
#       <td>0.459307</td>
#       <td>0.830689</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.465830</td>
#       <td>0.367022</td>
#       <td>0.866685</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.386849</td>
#       <td>0.378101</td>
#       <td>0.858958</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.368745</td>
#       <td>0.372821</td>
#       <td>0.859715</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.319241</td>
#       <td>0.295291</td>
#       <td>0.889896</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.298704</td>
#       <td>0.322990</td>
#       <td>0.887987</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.285236</td>
#       <td>0.261091</td>
#       <td>0.911029</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.271346</td>
#       <td>0.306571</td>
#       <td>0.882875</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.223567</td>
#       <td>0.275681</td>
#       <td>0.901359</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.191109</td>
#       <td>0.302734</td>
#       <td>0.891443</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [23/23 00:02<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 3.233546018600464.
# Better model found at epoch 1 with valid_loss value: 0.5677316784858704.
# Better model found at epoch 2 with valid_loss value: 0.45930737257003784.
# Better model found at epoch 3 with valid_loss value: 0.367021769285202.
# Better model found at epoch 6 with valid_loss value: 0.29529139399528503.
# Better model found at epoch 8 with valid_loss value: 0.261091411113739.
# Epoch 12: early stopping
# Model save as: EfficientNetB2WithPreprocessing

# %%
import scipy as sp
class OptimizedRounder(object):
    """
    Optimize threshold coefficients.
    """
    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        """
        Customized loss function.
        
        :param coef: list, shape=[4]
            Threshold.
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        
        # Cohen's kappa: a statistic that measures inter-annotator agreement.
        ll = metrics.cohen_kappa_score(y, X_p, weights='quadratic')
        return -ll

    def fit(self, X, y):
        """
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        # new function with partial application of the given arguments and keywords.
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        initial_coef = [0.5, 1.5, 2.5, 3.5]
        # Minimization of scalar function of one or more variables.
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method='nelder-mead')
        print(-loss_partial(self.coef_['x']))

    def predict(self, X, coef):
        """
        :param X: list, shape=[5]
            Prediction.
        :param coef: list, shape=[4]
            Threshold.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        return X_p

    def coefficients(self):
        return self.coef_['x']

# %%
learn.data.add_test(ImageList.from_df(test_df,
                                      '2019data',
                                      folder='test_images_ben_preprocessing_sigmaX10',
                                      suffix='.png'))
valid_preds = learn.get_preds(ds_type=DatasetType.Valid)
optR = OptimizedRounder()
optR.fit(valid_preds[0],valid_preds[1])
coefficients = optR.coefficients()
print(coefficients)
# Out:
# 0.9169743961388123
# [0.556569 1.632377 2.303207 3.041678]

# %%
df_2015 = pd.read_csv('aptos-data-split/df_2015_cv.csv')
df_2019 = pd.read_csv('aptos-data-split/df_2019_cv.csv')



df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]
bs = 32 #smaller batch size is better for training, but may take longer
sz = 256  # get model input size
# sz = EfficientNet.get_image_size(model_name)  # get model input size
tfms = get_transforms(do_flip=True,flip_vert=True, max_rotate=0, max_zoom=1.2, max_warp=0)
df_2019test = pd.read_csv('2019data/train.csv')
train_2019="2019data/train_images_ben_preprocessing_sigmaX10/"
df_2019['path'] = df_2019test['id_code'].map(lambda x: os.path.join(train_2019, '{}.png'.format(x)))


df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]

# test_df = pd.read_csv('2019data/sample_submission.csv')

data = (ImageList.from_df(df=df,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )

def qk(y_pred, y):
    return torch.tensor(cohen_kappa_score(torch.round(y_pred), y, weights='quadratic'), device='cuda:0')

model_name = 'efficientnet-b2'
model = EfficientNet.from_pretrained(model_name, num_classes=1)

learn = Learner(data, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = 'output/models/')
# Out:
# Loaded pretrained weights for efficientnet-b2

# %%
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='76' class='' max='1097' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.93% [76/1097 00:20<04:35 4.1685]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.09E-05
# Min loss divided by 10: 1.58E-07

# %%
model_save_name = "EfficientNetB2Data2015"
# min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(30, 2.09E-05, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       46.67% [14/30 1:08:37<1:18:25]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.035439</td>
#       <td>2.566333</td>
#       <td>-0.003677</td>
#       <td>04:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.876665</td>
#       <td>2.153163</td>
#       <td>-0.015433</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.717201</td>
#       <td>1.742658</td>
#       <td>0.231857</td>
#       <td>04:52</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.622091</td>
#       <td>1.574495</td>
#       <td>0.350229</td>
#       <td>04:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.565070</td>
#       <td>1.526815</td>
#       <td>0.374695</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.522308</td>
#       <td>1.414981</td>
#       <td>0.427482</td>
#       <td>04:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.492188</td>
#       <td>1.471995</td>
#       <td>0.413225</td>
#       <td>04:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.472627</td>
#       <td>1.543272</td>
#       <td>0.385987</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.445027</td>
#       <td>1.399715</td>
#       <td>0.442721</td>
#       <td>04:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.420227</td>
#       <td>1.228510</td>
#       <td>0.516475</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.390929</td>
#       <td>1.148487</td>
#       <td>0.548875</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.389363</td>
#       <td>1.249944</td>
#       <td>0.505597</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.372293</td>
#       <td>1.461699</td>
#       <td>0.408583</td>
#       <td>04:55</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.355783</td>
#       <td>1.405129</td>
#       <td>0.437322</td>
#       <td>04:54</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='115' class='' max='115' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [115/115 00:09<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 2.5663325786590576.
# Better model found at epoch 1 with valid_loss value: 2.153162956237793.
# Better model found at epoch 2 with valid_loss value: 1.7426578998565674.
# Better model found at epoch 3 with valid_loss value: 1.5744951963424683.
# Better model found at epoch 4 with valid_loss value: 1.5268148183822632.
# Better model found at epoch 5 with valid_loss value: 1.4149812459945679.
# Better model found at epoch 8 with valid_loss value: 1.3997153043746948.
# Better model found at epoch 9 with valid_loss value: 1.2285102605819702.
# Better model found at epoch 10 with valid_loss value: 1.1484873294830322.
# Epoch 14: early stopping
# Model save as: EfficientNetB2Data2015

# %%
df_2019test = pd.read_csv('2019data/train.csv')
train_2019="2019data/train_images_ben_preprocessing_sigmaX10/"
df_2019test['path'] = df_2019test['id_code'].map(lambda x: os.path.join(train_2019, '{}.png'.format(x)))
df_2019test['is_valid'] = [False]*2929 + [True]*733 

data_2020 = (ImageList.from_df(df=df_2019test,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
learn = Learner(data_2020, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = 'output/models/')
learn.load("EfficientNetB2Data2015")
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: FloatList
# 2.0,4.0,1.0,0.0,0.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: FloatList
# 0.0,1.0,0.0,4.0,2.0
# Path: .;
#
# Test: None, model=EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         16, 16, kernel_size=(3, 3), stride=(1, 1), groups=16, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         16, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 16, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=[2, 2], groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(5, 5), stride=[1, 1], groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=[2, 2], groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(3, 3), stride=[1, 1], groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2112, 2112, kernel_size=(3, 3), stride=(1, 1), groups=2112, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2112, 88, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         88, 2112, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1408, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.3, inplace=False)
#   (_fc): Linear(in_features=1408, out_features=1, bias=True)
#   (_swish): MemoryEfficientSwish()
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of MSELoss(), metrics=[<function qk at 0x7f90aee119e0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='output/models/', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False), functools.partial(<class 'fastai.callbacks.tracker.EarlyStoppingCallback'>, min_delta=0, patience=3)], callbacks=[], layer_groups=[Sequential(
#   (0): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (1): ParameterModule()
#   (2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (17): ParameterModule()
#   (18): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): Identity()
#   (20): ParameterModule()
#   (21): ParameterModule()
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (28): MemoryEfficientSwish()
#   (29): Identity()
#   (30): ParameterModule()
#   (31): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (32): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (33): ParameterModule()
#   (34): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): Identity()
#   (36): ParameterModule()
#   (37): ParameterModule()
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (44): MemoryEfficientSwish()
#   (45): Identity()
#   (46): ParameterModule()
#   (47): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (48): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (49): ParameterModule()
#   (50): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): Identity()
#   (52): ParameterModule()
#   (53): ParameterModule()
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (60): MemoryEfficientSwish()
#   (61): Identity()
#   (62): ParameterModule()
#   (63): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (64): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (65): ParameterModule()
#   (66): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): Identity()
#   (68): ParameterModule()
#   (69): ParameterModule()
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (76): MemoryEfficientSwish()
#   (77): Identity()
#   (78): ParameterModule()
#   (79): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (80): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (81): ParameterModule()
#   (82): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): Identity()
#   (84): ParameterModule()
#   (85): ParameterModule()
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (92): MemoryEfficientSwish()
#   (93): Identity()
#   (94): ParameterModule()
#   (95): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (96): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (97): ParameterModule()
#   (98): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): Identity()
#   (100): ParameterModule()
#   (101): ParameterModule()
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (108): MemoryEfficientSwish()
#   (109): Identity()
#   (110): ParameterModule()
#   (111): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (112): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (113): ParameterModule()
#   (114): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (115): Identity()
#   (116): ParameterModule()
#   (117): ParameterModule()
#   (118): Identity()
#   (119): ParameterModule()
#   (120): ParameterModule()
#   (121): Identity()
#   (122): ParameterModule()
#   (123): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (124): MemoryEfficientSwish()
#   (125): Identity()
#   (126): ParameterModule()
#   (127): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (128): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (129): ParameterModule()
#   (130): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (131): Identity()
#   (132): ParameterModule()
#   (133): ParameterModule()
#   (134): Identity()
#   (135): ParameterModule()
#   (136): ParameterModule()
#   (137): Identity()
#   (138): ParameterModule()
#   (139): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (140): MemoryEfficientSwish()
#   (141): Identity()
#   (142): ParameterModule()
#   (143): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (144): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (145): ParameterModule()
#   (146): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (147): Identity()
#   (148): ParameterModule()
#   (149): ParameterModule()
#   (150): Identity()
#   (151): ParameterModule()
#   (152): ParameterModule()
#   (153): Identity()
#   (154): ParameterModule()
#   (155): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (156): MemoryEfficientSwish()
#   (157): Identity()
#   (158): ParameterModule()
#   (159): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (160): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (161): ParameterModule()
#   (162): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (163): Identity()
#   (164): ParameterModule()
#   (165): ParameterModule()
#   (166): Identity()
#   (167): ParameterModule()
#   (168): ParameterModule()
#   (169): Identity()
#   (170): ParameterModule()
#   (171): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (172): MemoryEfficientSwish()
#   (173): Identity()
#   (174): ParameterModule()
#   (175): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (176): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (177): ParameterModule()
#   (178): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (179): Identity()
#   (180): ParameterModule()
#   (181): ParameterModule()
#   (182): Identity()
#   (183): ParameterModule()
#   (184): ParameterModule()
#   (185): Identity()
#   (186): ParameterModule()
#   (187): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (188): MemoryEfficientSwish()
#   (189): Identity()
#   (190): ParameterModule()
#   (191): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (192): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (193): ParameterModule()
#   (194): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (195): Identity()
#   (196): ParameterModule()
#   (197): ParameterModule()
#   (198): Identity()
#   (199): ParameterModule()
#   (200): ParameterModule()
#   (201): Identity()
#   (202): ParameterModule()
#   (203): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (204): MemoryEfficientSwish()
#   (205): Identity()
#   (206): ParameterModule()
#   (207): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (208): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (209): ParameterModule()
#   (210): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (211): Identity()
#   (212): ParameterModule()
#   (213): ParameterModule()
#   (214): Identity()
#   (215): ParameterModule()
#   (216): ParameterModule()
#   (217): Identity()
#   (218): ParameterModule()
#   (219): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (220): MemoryEfficientSwish()
#   (221): Identity()
#   (222): ParameterModule()
#   (223): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (224): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (225): ParameterModule()
#   (226): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (227): Identity()
#   (228): ParameterModule()
#   (229): ParameterModule()
#   (230): Identity()
#   (231): ParameterModule()
#   (232): ParameterModule()
#   (233): Identity()
#   (234): ParameterModule()
#   (235): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (236): MemoryEfficientSwish()
#   (237): Identity()
#   (238): ParameterModule()
#   (239): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (240): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (241): ParameterModule()
#   (242): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): Identity()
#   (244): ParameterModule()
#   (245): ParameterModule()
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (252): MemoryEfficientSwish()
#   (253): Identity()
#   (254): ParameterModule()
#   (255): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (256): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (257): ParameterModule()
#   (258): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): Identity()
#   (260): ParameterModule()
#   (261): ParameterModule()
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (268): MemoryEfficientSwish()
#   (269): Identity()
#   (270): ParameterModule()
#   (271): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (272): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (273): ParameterModule()
#   (274): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): Identity()
#   (276): ParameterModule()
#   (277): ParameterModule()
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (284): MemoryEfficientSwish()
#   (285): Identity()
#   (286): ParameterModule()
#   (287): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (288): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (289): ParameterModule()
#   (290): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): Identity()
#   (292): ParameterModule()
#   (293): ParameterModule()
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (300): MemoryEfficientSwish()
#   (301): Identity()
#   (302): ParameterModule()
#   (303): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (304): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (305): ParameterModule()
#   (306): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): Identity()
#   (308): ParameterModule()
#   (309): ParameterModule()
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (316): MemoryEfficientSwish()
#   (317): Identity()
#   (318): ParameterModule()
#   (319): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (320): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (321): ParameterModule()
#   (322): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): Identity()
#   (324): ParameterModule()
#   (325): ParameterModule()
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (332): MemoryEfficientSwish()
#   (333): Identity()
#   (334): ParameterModule()
#   (335): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (336): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (337): ParameterModule()
#   (338): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): Identity()
#   (340): ParameterModule()
#   (341): ParameterModule()
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (348): MemoryEfficientSwish()
#   (349): Identity()
#   (350): ParameterModule()
#   (351): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (352): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (353): ParameterModule()
#   (354): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): Identity()
#   (356): ParameterModule()
#   (357): ParameterModule()
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (364): MemoryEfficientSwish()
#   (365): Identity()
#   (366): ParameterModule()
#   (367): BatchNorm2d(1408, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (368): AdaptiveAvgPool2d(output_size=1)
#   (369): Dropout(p=0.3, inplace=False)
#   (370): Linear(in_features=1408, out_features=1, bias=True)
#   (371): MemoryEfficientSwish()
# )], add_time=True, silent=False)

# %%
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='73' class='' max='91' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.22% [73/91 00:15<00:03 2.3547]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.32E-06
# Min loss divided by 10: 1.45E-04

# %%
model_save_name = "EfficientNetB2TrasferLearning2"
# min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(50, 1.32E-06, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='41' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.00% [41/50 14:34<03:12]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.132564</td>
#       <td>0.857641</td>
#       <td>0.673260</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.110755</td>
#       <td>0.802291</td>
#       <td>0.709208</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.105802</td>
#       <td>0.818039</td>
#       <td>0.691382</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.098603</td>
#       <td>0.823273</td>
#       <td>0.699359</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.066962</td>
#       <td>0.820350</td>
#       <td>0.702302</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.987366</td>
#       <td>0.783374</td>
#       <td>0.711023</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.955818</td>
#       <td>0.747492</td>
#       <td>0.724632</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.900179</td>
#       <td>0.720731</td>
#       <td>0.733535</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.826614</td>
#       <td>0.679731</td>
#       <td>0.750915</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.815606</td>
#       <td>0.650676</td>
#       <td>0.755517</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.774774</td>
#       <td>0.614302</td>
#       <td>0.769948</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.707532</td>
#       <td>0.572936</td>
#       <td>0.789012</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.670856</td>
#       <td>0.551523</td>
#       <td>0.800966</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.661447</td>
#       <td>0.538945</td>
#       <td>0.803827</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.618845</td>
#       <td>0.514851</td>
#       <td>0.809676</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.584550</td>
#       <td>0.486546</td>
#       <td>0.827323</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.574830</td>
#       <td>0.470177</td>
#       <td>0.828619</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.519330</td>
#       <td>0.456849</td>
#       <td>0.835481</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.518077</td>
#       <td>0.445149</td>
#       <td>0.837342</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.514383</td>
#       <td>0.440151</td>
#       <td>0.841961</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.499339</td>
#       <td>0.428173</td>
#       <td>0.848760</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.496439</td>
#       <td>0.423828</td>
#       <td>0.849961</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.477098</td>
#       <td>0.415684</td>
#       <td>0.854717</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.494884</td>
#       <td>0.410424</td>
#       <td>0.857014</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.490223</td>
#       <td>0.406030</td>
#       <td>0.859937</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.458888</td>
#       <td>0.402899</td>
#       <td>0.858259</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.427592</td>
#       <td>0.395481</td>
#       <td>0.858597</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.444107</td>
#       <td>0.392566</td>
#       <td>0.857712</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.453299</td>
#       <td>0.390785</td>
#       <td>0.859696</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.450400</td>
#       <td>0.388322</td>
#       <td>0.861807</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.433175</td>
#       <td>0.385457</td>
#       <td>0.865916</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.439704</td>
#       <td>0.384251</td>
#       <td>0.866049</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.448241</td>
#       <td>0.385246</td>
#       <td>0.865934</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.448514</td>
#       <td>0.384847</td>
#       <td>0.866130</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.456176</td>
#       <td>0.383777</td>
#       <td>0.866647</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.425733</td>
#       <td>0.383923</td>
#       <td>0.866647</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.415107</td>
#       <td>0.381035</td>
#       <td>0.866755</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.417053</td>
#       <td>0.378028</td>
#       <td>0.863847</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.401360</td>
#       <td>0.378623</td>
#       <td>0.864553</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.429543</td>
#       <td>0.380824</td>
#       <td>0.863553</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.443727</td>
#       <td>0.378054</td>
#       <td>0.864572</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [23/23 00:02<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 0.8576406836509705.
# Better model found at epoch 1 with valid_loss value: 0.8022913932800293.
# Better model found at epoch 5 with valid_loss value: 0.7833738923072815.
# Better model found at epoch 6 with valid_loss value: 0.7474923133850098.
# Better model found at epoch 7 with valid_loss value: 0.7207314968109131.
# Better model found at epoch 8 with valid_loss value: 0.6797307729721069.
# Better model found at epoch 9 with valid_loss value: 0.6506757140159607.
# Better model found at epoch 10 with valid_loss value: 0.6143017411231995.
# Better model found at epoch 11 with valid_loss value: 0.5729355812072754.
# Better model found at epoch 12 with valid_loss value: 0.5515226721763611.
# Better model found at epoch 13 with valid_loss value: 0.538944661617279.
# Better model found at epoch 14 with valid_loss value: 0.5148512125015259.
# Better model found at epoch 15 with valid_loss value: 0.4865456223487854.
# Better model found at epoch 16 with valid_loss value: 0.47017720341682434.
# Better model found at epoch 17 with valid_loss value: 0.4568486511707306.
# Better model found at epoch 18 with valid_loss value: 0.44514918327331543.
# Better model found at epoch 19 with valid_loss value: 0.4401511251926422.
# Better model found at epoch 20 with valid_loss value: 0.42817339301109314.
# Better model found at epoch 21 with valid_loss value: 0.42382779717445374.
# Better model found at epoch 22 with valid_loss value: 0.4156836271286011.
# Better model found at epoch 23 with valid_loss value: 0.4104236960411072.
# Better model found at epoch 24 with valid_loss value: 0.4060302674770355.
# Better model found at epoch 25 with valid_loss value: 0.4028993546962738.
# Better model found at epoch 26 with valid_loss value: 0.395481139421463.
# Better model found at epoch 27 with valid_loss value: 0.3925659656524658.
# Better model found at epoch 28 with valid_loss value: 0.390785276889801.
# Better model found at epoch 29 with valid_loss value: 0.3883224129676819.
# Better model found at epoch 30 with valid_loss value: 0.38545724749565125.
# Better model found at epoch 31 with valid_loss value: 0.3842514157295227.
# Better model found at epoch 34 with valid_loss value: 0.38377660512924194.
# Better model found at epoch 36 with valid_loss value: 0.3810347318649292.
# Better model found at epoch 37 with valid_loss value: 0.37802791595458984.
# Epoch 41: early stopping
# Model save as: EfficientNetB2TrasferLearning2

# %%
df_2019test = pd.read_csv('2019data/train.csv')
train_2019="2019data/train_images_ben_preprocessing_sigmaX10/"
df_2019test['path'] = df_2019test['id_code'].map(lambda x: os.path.join(train_2019, '{}.png'.format(x)))
df_2019test['is_valid'] = [False]*2929 + [True]*733 

data_2020 = (ImageList.from_df(df=df_2019test,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
learn = Learner(data_2020, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = 'output/models/')
learn.load("EfficientNetB2Data2015")
